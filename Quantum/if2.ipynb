# %%
from qiskit_aer import AerSimulator
from qiskit import QuantumCircuit, QuantumRegister,ClassicalRegister, transpile

from IPython.display import Math
from qc_workbook.show_state import statevector_expr

import numpy as np

print("----Start----")
simulator = AerSimulator(method='statevector')
print(simulator.name)
# Out:
# ----Start----
# aer_simulator_statevector

# %%
register1 = QuantumRegister(4, name='reg1')
register2 = QuantumRegister(1, name='reg2')


circuit = QuantumCircuit(register1, register2)
circuit.h(register1)

# %%
dtheta = 2. * np.pi / 16.

for idx in range(4):
        circuit.cry( dtheta*(2**idx), register1[idx], register2[0])

circuit.draw('mpl')

# %%
lines = statevector_expr(circuit, register_sizes=[4, 1], terms_per_row=6)
for line in lines:
    display(Math(line))
# Out:
# $\displaystyle | \text{final} \rangle = 0.250 |0:0\rangle + 0.245 |0:1\rangle + 0.231 |0:2\rangle + 0.208 |0:3\rangle + 0.177 |0:4\rangle + 0.139 |0:5\rangle$
# $\displaystyle  + 0.096 |0:6\rangle + 0.049 |0:7\rangle - 0.049 |0:9\rangle - 0.096 |0:10\rangle - 0.139 |0:11\rangle - 0.177 |0:12\rangle$
# $\displaystyle  - 0.208 |0:13\rangle - 0.231 |0:14\rangle - 0.245 |0:15\rangle + 0.049 |1:1\rangle + 0.096 |1:2\rangle + 0.139 |1:3\rangle$
# $\displaystyle  + 0.177 |1:4\rangle + 0.208 |1:5\rangle + 0.231 |1:6\rangle + 0.245 |1:7\rangle + 0.250 |1:8\rangle + 0.245 |1:9\rangle$
# $\displaystyle  + 0.231 |1:10\rangle + 0.208 |1:11\rangle + 0.177 |1:12\rangle + 0.139 |1:13\rangle + 0.096 |1:14\rangle + 0.049 |1:15\rangle$
